# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
columns=['class','Alcohol', 'Malicacid','Ash','Alcalinity of ash'  , 'Magnesium', 'Total phenols', 'Flavanoids','Nonflavanoid phenols', 'Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline  ']
# columns=[i for
df = pd.read_csv("wine.data",names=columns,delimiter=",")
df.head()
# Out:
#    class  Alcohol  Malicacid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23       1.71  2.43               15.6        127
# 1      1    13.20       1.78  2.14               11.2        100
# 2      1    13.16       2.36  2.67               18.6        101
# 3      1    14.37       1.95  2.50               16.8        113
# 4      1    13.24       2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92       1065
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df[columns[1:]], df[columns[0]], test_size=0.33, random_state=42)

# %%
k=3

# %%
ran=np.random.randint(0,X_train.shape[0],k)
ran
# Out:
# array([ 8, 62, 61])

# %%
train=np.array(X_train)
train.shape
# Out:
# (119, 13)

# %%
centroids=train[ran]
centroids
# Out:
# array([[1.225e+01, 3.880e+00, 2.200e+00, 1.850e+01, 1.120e+02, 1.380e+00,
#         7.800e-01, 2.900e-01, 1.140e+00, 8.210e+00, 6.500e-01, 2.000e+00,
#         8.550e+02],
#        [1.351e+01, 1.800e+00, 2.650e+00, 1.900e+01, 1.100e+02, 2.350e+00,
#         2.530e+00, 2.900e-01, 1.540e+00, 4.200e+00, 1.100e+00, 2.870e+00,
#         1.095e+03],
#        [1.184e+01, 2.890e+00, 2.230e+00, 1.800e+01, 1.120e+02, 1.720e+00,
#         1.320e+00, 4.300e-01, 9.500e-01, 2.650e+00, 9.600e-01, 2.520e+00,
#         5.000e+02]])

# %%
def update_assignments(data, centroids):   
    c = []
    for i in data:
        c.append(np.argmin(np.sum((i.reshape((1, 13)) - centroids) ** 2, axis=1)))
#         print(c)
    return c

# %%
def update_centroids(data, num_clusters, assignments):
    cen = []
    for c in range(len(num_clusters)):
        cen.append(np.mean([data[x] for x in range(len(data)) if assignments[x] == c], axis=0))
    return cen

# %%
data =np.array(X_train)
print(data.shape)
data
# Out:
# (119, 13)
# array([[1.371e+01, 1.860e+00, 2.360e+00, ..., 1.110e+00, 4.000e+00,
#         1.035e+03],
#        [1.388e+01, 5.040e+00, 2.230e+00, ..., 5.800e-01, 1.330e+00,
#         4.150e+02],
#        [1.229e+01, 1.410e+00, 1.980e+00, ..., 1.230e+00, 2.740e+00,
#         4.280e+02],
#        ...,
#        [1.438e+01, 1.870e+00, 2.380e+00, ..., 1.200e+00, 3.000e+00,
#         1.547e+03],
#        [1.269e+01, 1.530e+00, 2.260e+00, ..., 9.600e-01, 2.060e+00,
#         4.950e+02],
#        [1.234e+01, 2.450e+00, 2.460e+00, ..., 8.000e-01, 3.380e+00,
#         4.380e+02]])

# %%
for i in range(100):
    a = update_assignments(data, centroids)
    centroids = update_centroids(data, centroids, a)
    centroids = np.array(centroids)

# %%
 def euclidian_distance(query,X):
        Sub=X-np.array(query)
        sqr=np.square(Sub)
        add=np.sum(sqr,axis=1)
        dis=np.sqrt(add)
        return dis

# %%
 def test(query,centtroids):
        euclidian_distance(query,centroids)
        near=np.argsort(dis)[:self.k]

# %%
centroids
X_test
# Out:
#      Alcohol  Malicacid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 19     13.64       3.10  2.56               15.2        116           2.70
# 45     14.21       4.04  2.44               18.9        111           2.85
# 140    12.93       2.81  2.70               21.0         96           1.54
# 30     13.73       1.50  2.70               22.5        101           3.00
# 67     12.37       1.17  1.92               19.6         78           2.11
# 16     14.30       1.92  2.72               20.0        120           2.80
# 119    12.00       3.43  2.00               19.0         87           2.00
# 174    13.40       3.91  2.48               23.0        102           1.80
# 109    11.61       1.35  2.70               20.0         94           2.74
# 141    13.36       2.56  2.35               20.0         89           1.40
# 24     13.50       1.81  2.61               20.0         96           2.53
# ...

# %%
if __name__ == "__main__":
    print("hello")
# Out:
# hello
